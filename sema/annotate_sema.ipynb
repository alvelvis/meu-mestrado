# %%
import os
if not os.path.isfile("estrutura_ud.py"):
    ! wget https://raw.githubusercontent.com/alvelvis/ACDC-UD/master/estrutura_ud.py
import estrutura_ud
try:
    import stanza
except Exception:
    ! pip3 install stanza
    import stanza
    stanza.download('pt')
nlp = stanza.Pipeline('pt')
import pprint
import shutil
import unicodedata
import itertools
# Out:
# 2021-04-17 17:23:47 INFO: Loading these models for language: pt (Portuguese):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | bosque  |
# | mwt       | bosque  |
# | pos       | bosque  |
# | lemma     | bosque  |
# | depparse  | bosque  |
# =======================
#
# 2021-04-17 17:23:47 INFO: Use device: gpu
# 2021-04-17 17:23:47 INFO: Loading: tokenize
# 2021-04-17 17:24:05 INFO: Loading: mwt
# 2021-04-17 17:24:05 INFO: Loading: pos
# 2021-04-17 17:24:06 INFO: Loading: lemma
# 2021-04-17 17:24:06 INFO: Loading: depparse
# 2021-04-17 17:24:08 INFO: Done loading processors!

# %%
tagset_folder = "tagset"
conllu_folder = "conllu"

for folder in [tagset_folder, conllu_folder]:
    if not os.path.isdir(folder):
        os.mkdir(folder)

col_sema = 8
files = {}
tags = {}
lemmas = {
    'ums': 'ums',
    'santos': 'santos',
    'estai': 'estai',
    'veio': 'veio'
}

if not all(os.path.isdir(x) for x in [tagset_folder, conllu_folder]):
    raise Exception("Folder not found.")

def remove_accents(input_str):
    nfkd_form = unicodedata.normalize('NFKD', input_str)
    return u"".join([c for c in nfkd_form if not unicodedata.combining(c)])

def stanza_lemmatize(string):
    doc = nlp(string)
    return " ".join([token['lemma'] for sentence in doc.to_dict() for token in sentence if 'lemma' in token])

def count_tokens(string):
    return {
        'tokens': len(list(filter(lambda x: len(x.split("\t")) == 10, string.splitlines()))),
        'sentences': len([x for x in string.split("\n\n") if x.strip()]),
        'types': {x.split("\t")[1] for x in filter(lambda x: len(x.split("\t")) == 10, string.splitlines())},
        }

def tag_sentence(sentence, entity, tag):
    tokens = list(filter(lambda x: isinstance(x, list) and not '-' in x[0], sentence))
    metadata = list(filter(lambda x: isinstance(x, str), sentence))
    mwt = {l: line for l, line in enumerate(sentence) if isinstance(line, list) and '-' in line[0]}
    ngram_span = len(entity)
    for t, token in enumerate(tokens):
        if t + ngram_span > len(tokens):
            break
        ngram_word = [remove_accents(tokens[t+i][1].lower()) for i in range(ngram_span)]
        ngram_lemma = [remove_accents(tokens[t+i][2].lower()) for i in range(ngram_span)]
        if any(x == entity for x in [ngram_word, ngram_lemma]):
            if entity[0] == "campos" and tokens[t][0][0] != "C":
                continue
            for i in range(ngram_span):
                tokens[t+i][col_sema] = "|".join(set([x for x in tokens[t+i][col_sema].split("|") if x != "O"] + ["{}={}".format("I" if i else "B", tag)]))
    sentence = metadata + tokens
    for line in mwt:
        sentence.insert(line, mwt[line])
    return sentence

def count_tags(text):
    frequency = []
    for token in filter(lambda x: len(x.split("\t")) == 10 and not '-' in x.split("\t")[0] and "B=" in x.split("\t")[col_sema], text.splitlines()):
        frequency.extend([x.replace("B=", "") for x in token.split("\t")[col_sema].split("|") if x.startswith("B=")])
    return frequency

def apply_rules(text):
    corpus = estrutura_ud.Corpus()
    corpus.build(text)
    for sentence in corpus.sentences.values():
        for token in sentence.tokens:
            pass
    return corpus.to_str()

# Build tagset lexicon
for file in os.listdir(tagset_folder):
    if file.lower().endswith(".txt"):
        tag = file.upper().split(".TXT")[0].replace("_", ":").replace(" ", "_")
        with open("{}/{}".format(tagset_folder, file)) as f:
            text = f.read()
        tags[tag] = set([x.strip().lower() for x in text.splitlines() if not x.strip().startswith("#") and x.strip()])

# Load conllu files and gather initial statistics
for file in os.listdir(conllu_folder):
    if file.lower().endswith(".conllu"):
        with open("{}/{}".format(conllu_folder, file)) as f:
            text = f.read()
        sentences = [x.splitlines() for x in text.split("\n\n") if x.strip()]
        for s, sentence in enumerate(sentences):
            for l, line in enumerate(sentence):
                if len(line.split("\t")) == 10:
                    sentences[s][l] = line.split("\t")
                    sentences[s][l][col_sema] = "O"
        files[file] = {'text': text, 'tagged': sentences, 'tags_frequency': []}
        files[file].update(count_tokens(files[file]['text']))

# Tag each file
for f, file in enumerate(files):
    text_normalized = remove_accents(files[file]['text'].lower())
    for t, tag in enumerate(tags):
        for e, entity in enumerate(list(filter(lambda x: remove_accents(x) in text_normalized, tags[tag]))):
            if not entity in lemmas:
                lemmas[entity] = stanza_lemmatize(entity)
            print("{}/{} - {}/{} - {} / {}: {} - {} {}".format(f+1, len(files), t+1, len(tags), e+1, len(tags[tag]), entity, lemmas[entity], "-- skip lemma" if lemmas[entity] == entity else ""))
            for ngram in [entity, lemmas[entity] if lemmas[entity] != entity else ""]:
                if ngram:
                    for s, sentence in enumerate(files[file]['tagged']):
                        files[file]['tagged'][s] = tag_sentence(sentence, [remove_accents(x) for x in ngram.split(" ")], tag)        
    files[file]['output'] = files[file]['tagged'][:]
    for s, sentence in enumerate(files[file]['tagged']):
        for t, token in enumerate(sentence):
            if isinstance(token, list):
                files[file]['output'][s][t] = "\t".join(files[file]['output'][s][t])
        files[file]['output'][s] = "\n".join(files[file]['output'][s])
    files[file]['output'] = "\n\n".join(files[file]['output'])
    files[file]['output'] = apply_rules(files[file]['output'])
    files[file]['tags_frequency'].extend(count_tags(files[file]['output']))
# Out:
# -som -- skip lemma
# 325/330 - 10/19 - 3 / 287: trado - trado -- skip lemma
# 325/330 - 11/19 - 1 / 387: ostra - ostra -- skip lemma
# 325/330 - 11/19 - 2 / 387: serra - serra -- skip lemma
# 325/330 - 11/19 - 3 / 387: cacao - cacao -- skip lemma
# 325/330 - 12/19 - 1 / 100: td - td -- skip lemma
# 325/330 - 12/19 - 2 / 100: bram - bram -- skip lemma
# 325/330 - 12/19 - 3 / 100: cni - cni -- skip lemma
# 325/330 - 12/19 - 4 / 100: sma - sma -- skip lemma
# 325/330 - 12/19 - 5 / 100: pf - pf -- skip lemma
# 325/330 - 12/19 - 6 / 100: semp - semp -- skip lemma
# 325/330 - 12/19 - 7 / 100: unifor - unifor -- skip lemma
# 325/330 - 14/19 - 1 / 65: acre - acre -- skip lemma
# 325/330 - 14/19 - 2 / 65: ceará - ceará -- skip lemma
# 325/330 - 14/19 - 3 / 65: ico - ico -- skip lemma
# 325/330 - 16/19 - 1 / 284: pu - pu -- skip lemma
# 325/330 - 16/19 - 2 / 284: aço-carbono - aço-carbono -- skip lemma
# 325/330 - 16/19 - 3 / 284: soluto - soluto -- skip lemma
# 325/330 - 16/19 - 4 / 284: re - re -- skip lemma
# 325/330 - 16/19 - 5 / 284: pet - pet -- skip lemma
# 325/330 - 16/19 - 6 / 284: amina - amina -- skip lemma
# 325/330 - 16/19 - 7 / 284: óxidos - óxidos -- skip lemma
# 325/330 - 16/19 - 8 / 284: estrôncio - estrôncio -- skip lemma
# 325/330 - 16/19 - 9 / 284: co - co -- skip lemma
# 325/330 - 16/19 - 10 / 284: éster - éster -- skip lemma
# 325/330 - 16/19 - 11 / 284: poli - poli -- skip lemma
# 325/330 - 16/19 - 12 / 284: co2 - co2 -- skip lemma
# 325/330 - 18/19 - 1 / 159: gas - gas -- skip lemma
# 325/330 - 18/19 - 2 / 159: gás - gás -- skip lemma
# 325/330 - 18/19 - 3 / 159: oleo - oleo -- skip lemma
# 325/330 - 18/19 - 4 / 159: óleo - óleo -- skip lemma
# 325/330 - 18/19 - 5 / 159: petroleo - petroleo -- skip lemma
# 325/330 - 18/19 - 6 / 159: petróleo - petróleo -- skip lemma
# 325/330 - 19/19 - 1 / 125: ceará - ceará -- skip lemma
# 325/330 - 19/19 - 2 / 125: belo horizonte - belo horizonte -- skip lemma
# build: 0.1380457878112793326/330 - 2/19 - 1 / 926: cré - cré -- skip lemma
# 326/330 - 2/19 - 2 / 926: ilita - ilita -- skip lemma
# 326/330 - 2/19 - 3 / 926: atrito - atrito -- skip lemma
# 326/330 - 2/19 - 4 / 926: sal - sal -- skip lemma
# 326/330 - 2/19 - 5 / 926: raiz - raiz -- skip lemma
# 326/330 - 2/19 - 6 / 926: alita - alita -- skip lemma
# 326/330 - 2/19 - 7 / 926: lisa - liso
# 326/330 - 2/19 - 8 / 926: escorregamento - escorregamento -- skip lemma
# 326/330 - 3/19 - 1 / 78: metódo dos elementos finitos - metódo de o elemento finito
# 326/330 - 3/19 - 2 / 78: método - método -- skip lemma
# 326/330 - 3/19 - 3 / 78: teste - teste -- skip lemma
# 326/330 - 4/19 - 1 / 41: aeronave - aeronave -- skip lemma
# 326/330 - 5/19 - 1 / 140: área de petróleo - área de petróleo -- skip lemma
# 326/330 - 5/19 - 2 / 140: duto - duto -- skip lemma
# 326/330 - 5/19 - 3 / 140: rias - ria
# 326/330 - 7/19 - 1 / 38: campo - campo -- skip lemma
# 326/330 - 10/19 - 1 / 287: ums - ums -- skip lemma
# 326/330 - 10/19 - 2 / 287: mapa - mapa -- skip lemma
# 326/330 - 10/19 - 3 / 287: equipamento - equipamento -- skip lemma
# 326/330 - 10/19 - 4 / 287: trado - trado -- skip lemma
# 326/330 - 10/19 - 5 / 287: pert - pert -- skip lemma
# 326/330 - 10/19 - 6 / 287: arado - arado -- skip lemma
# 326/330 - 10/19 - 7 / 287: filtro - filtro -- skip lemma
# 326/330 - 10/19 - 8 / 287: sobrepressão - sobrepressão -- skip lemma
# 326/330 - 10/19 - 9 / 287: mapas - mapa
# 326/330 - 11/19 - 1 / 387: ostra - ostra -- skip lemma
# 326/330 - 11/19 - 2 / 387: mero - mero -- skip lemma
# 326/330 - 11/19 - 3 / 387: vermelho - vermelho -- skip lemma
# 326/330 - 11/19 - 4 / 387: cacao - cacao -- skip lemma
# 326/330 - 12/19 - 1 / 100: bram - bram -- skip lemma
# 326/330 - 12/19 - 2 / 100: cni - cni -- skip lemma
# 326/330 - 12/19 - 3 / 100: ugn - ugn -- skip lemma
# 326/330 - 12/19 - 4 / 100: sma - sma -- skip lemma
# 326/330 - 12/19 - 5 / 100: pf - pf -- skip lemma
# 326/330 - 12/19 - 6 / 100: semp - semp -- skip lemma
# 326/330 - 12/19 - 7 / 100: unifor - unifor -- skip lemma
# 326/330 - 14/19 - 1 / 65: souza - souza -- skip lemma
# 326/330 - 14/19 - 2 / 65: acre - acre -- skip lemma
# 326/330 - 14/19 - 3 / 65: ico - ico -- skip lemma
# 326/330 - 16/19 - 1 / 284: cod - cod -- skip lemma
# 326/330 - 16/19 - 2 / 284: pu - pu -- skip lemma
# 326/330 - 16/19 - 3 / 284: soluto - soluto -- skip lemma
# 326/330 - 16/19 - 4 / 284: re - re -- skip lemma
# 326/330 - 16/19 - 5 / 284: pet - pet -- skip lemma
# 326/330 - 16/19 - 6 / 284: co - co -- skip lemma
# 326/330 - 16/19 - 7 / 284: poli - poli -- skip lemma
# 326/330 - 18/19 - 1 / 159: gas - gas -- skip lemma
# 326/330 - 18/19 - 2 / 159: gás - gás -- skip lemma
# 326/330 - 18/19 - 3 / 159: oleo - oleo -- skip lemma
# 326/330 - 18/19 - 4 / 159: óleo - óleo -- skip lemma
# 326/330 - 18/19 - 5 / 159: petroleo - petroleo -- skip lemma
# 326/330 - 18/19 - 6 / 159: petróleo - petróleo -- skip lemma
# 326/330 - 19/19 - 1 / 125: pei - pei -- skip lemma
# build: 1.1985974311828613327/330 - 2/19 - 1 / 926: junta - junta -- skip lemma
# 327/330 - 2/19 - 2 / 926: cristalina - cristalino
# 327/330 - 2/19 - 3 / 926: carvao - carvao -- skip lemma
# 327/330 - 2/19 - 4 / 926: cré - cré -- skip lemma
# 327/330 - 2/19 - 5 / 926: cristalino - cristalino -- skip lemma
# 327/330 - 2/19 - 6 / 926: lisa - liso
# 327/330 - 3/19 - 1 / 78: método - método -- skip lemma
# 327/330 - 3/19 - 2 / 78: teste - teste -- skip lemma
# 327/330 - 3/19 - 3 / 78: cromatografía líqüida - cromatografía líquido
# 327/330 - 3/19 - 4 / 78: vedação - vedação -- skip lemma
# 327/330 - 5/19 - 1 / 140: duto - duto -- skip lemma
# 327/330 - 5/19 - 2 / 140: estufa - estufa -- skip lemma
# 327/330 - 5/19 - 3 / 140: rias - ria
# 327/330 - 7/19 - 1 / 38: campo - campo -- skip lemma
# 327/330 - 10/19 - 1 / 287: estai - estai -- skip lemma
# 327/330 - 10/19 - 2 / 287: equipamento - equipamento -- skip lemma
# 327/330 - 10/19 - 3 / 287: trado - trado -- skip lemma
# 327/330 - 10/19 - 4 / 287: válvula - válvula -- skip lemma
# 327/330 - 10/19 - 5 / 287: arado - arado -- skip lemma
# 327/330 - 11/19 - 1 / 387: ostra - ostra -- skip lemma
# 327/330 - 11/19 - 2 / 387: serra - serra -- skip lemma
# 327/330 - 11/19 - 3 / 387: mero - mero -- skip lemma
# 327/330 - 11/19 - 4 / 387: vermelho - vermelho -- skip lemma
# 327/330 - 11/19 - 5 / 387: cacao - cacao -- skip lemma
# 327/330 - 12/19 - 1 / 100: cec - cec -- skip lemma
# 327/330 - 12/19 - 2 / 100: cni - cni -- skip lemma
# 327/330 - 12/19 - 3 / 100: sma - sma -- skip lemma
# 327/330 - 12/19 - 4 / 100: tp - tp -- skip lemma
# 327/330 - 12/19 - 5 / 100: wab - wab -- skip lemma
# 327/330 - 12/19 - 6 / 100: semp - semp -- skip lemma
# 327/330 - 13/19 - 1 / 45: diesel - diesel -- skip lemma
# 327/330 - 14/19 - 1 / 65: ico - ico -- skip lemma
# 327/330 - 14/19 - 2 / 65: santos - santos -- skip lemma
# 327/330 - 16/19 - 1 / 284: enzimas - enzima
# 327/330 - 16/19 - 2 / 284: pu - pu -- skip lemma
# 327/330 - 16/19 - 3 / 284: catalisadores - catalisador
# 327/330 - 16/19 - 4 / 284: re - re -- skip lemma
# 327/330 - 16/19 - 5 / 284: pet - pet -- skip lemma
# 327/330 - 16/19 - 6 / 284: álcali - álcali -- skip lemma
# 327/330 - 16/19 - 7 / 284: amina - amina -- skip lemma
# 327/330 - 16/19 - 8 / 284: alcalino - alcalino -- skip lemma
# 327/330 - 16/19 - 9 / 284: ptfe - ptfe -- skip lemma
# 327/330 - 16/19 - 10 / 284: resíduos - resíduo
# 327/330 - 16/19 - 11 / 284: co - co -- skip lemma
# 327/330 - 16/19 - 12 / 284: etano - etano -- skip lemma
# 327/330 - 16/19 - 13 / 284: poli - poli -- skip lemma
# 327/330 - 18/19 - 1 / 159: gas - gas -- skip lemma
# 327/330 - 18/19 - 2 / 159: gás - gás -- skip lemma
# 327/330 - 18/19 - 3 / 159: oleo - oleo -- skip lemma
# 327/330 - 18/19 - 4 / 159: óleo - óleo -- skip lemma
# 327/330 - 18/19 - 5 / 159: agua - agua -- skip lemma
# 327/330 - 18/19 - 6 / 159: óleo combustível - óleo combustível -- skip lemma
# 327/330 - 18/19 - 7 / 159: petroleo - petroleo -- skip lemma
# 327/330 - 18/19 - 8 / 159: água - água -- skip lemma
# 327/330 - 18/19 - 9 / 159: petróleo - petróleo -- skip lemma
# 327/330 - 19/19 - 1 / 125: santos - santos -- skip lemma
# 327/330 - 19/19 - 2 / 125: togo - togo -- skip lemma
# build: 0.14916491508483887328/330 - 2/19 - 1 / 926: junta - junta -- skip lemma
# 328/330 - 2/19 - 2 / 926: perfurações - perfuração
# 328/330 - 2/19 - 3 / 926: cré - cré -- skip lemma
# 328/330 - 2/19 - 4 / 926: ilita - ilita -- skip lemma
# 328/330 - 2/19 - 5 / 926: sal - sal -- skip lemma
# 328/330 - 2/19 - 6 / 926: lisa - liso
# 328/330 - 2/19 - 7 / 926: grafite - grafite -- skip lemma
# 328/330 - 2/19 - 8 / 926: sima - sima -- skip lemma
# 328/330 - 3/19 - 1 / 78: método - método -- skip lemma
# 328/330 - 3/19 - 2 / 78: cg - cg -- skip lemma
# 328/330 - 16/19 - 17 / 284: entalpia - entalpia -- skip lemma
# 328/330 - 16/19 - 18 / 284: co2 - co2 -- skip lemma
# 328/330 - 18/19 - 1 / 159: gas - gas -- skip lemma
# 328/330 - 18/19 - 2 / 159: gás - gás -- skip lemma
# 328/330 - 18/19 - 3 / 159: oleo - oleo -- skip lemma
# 328/330 - 18/19 - 4 / 159: óleo - óleo -- skip lemma
# 328/330 - 18/19 - 5 / 159: agua - agua -- skip lemma
# 328/330 - 18/19 - 6 / 159: óleo combustível - óleo combustível -- skip lemma
# 328/330 - 18/19 - 7 / 159: petroleo - petroleo -- skip lemma
# 328/330 - 18/19 - 8 / 159: água - água -- skip lemma
# 328/330 - 18/19 - 9 / 159: petróleo - petróleo -- skip lemma
# 328/330 - 19/19 - 1 / 125: rússia - rússia -- skip lemma
# 328/330 - 19/19 - 2 / 125: argentina - argentino
# 328/330 - 19/19 - 3 / 125: pei - pei -- skip lemma
# 328/330 - 19/19 - 4 / 125: suécia - suécia -- skip lemma
# build: 0.8445401191711426329/330 - 1/19 - 1 / 47: região crítica - região crítico
# 329/330 - 2/19 - 1 / 926: junta - junta -- skip lemma
# 329/330 - 2/19 - 2 / 926: pilares - pilar
# 329/330 - 2/19 - 3 / 926: cré - cré -- skip lemma
# 329/330 - 2/19 - 4 / 926: falha - falha -- skip lemma
# 329/330 - 2/19 - 5 / 926: atrito - atrito -- skip lemma
# 329/330 - 2/19 - 6 / 926: sal - sal -- skip lemma
# 329/330 - 2/19 - 7 / 926: fratura - fratura -- skip lemma
# 329/330 - 2/19 - 8 / 926: sulco - sulco -- skip lemma
# 329/330 - 2/19 - 9 / 926: lisa - liso
# 329/330 - 2/19 - 10 / 926: sima - sima -- skip lemma
# 329/330 - 3/19 - 1 / 78: método - método -- skip lemma
# 329/330 - 3/19 - 2 / 78: teste - teste -- skip lemma
# 329/330 - 3/19 - 3 / 78: superposição - superposição -- skip lemma
# 329/330 - 4/19 - 1 / 41: navio fpso - navio fpso -- skip lemma
# 329/330 - 4/19 - 2 / 41: submarino - submarino -- skip lemma
# 329/330 - 4/19 - 3 / 41: navio - navio -- skip lemma
# 329/330 - 5/19 - 1 / 140: duto - duto -- skip lemma
# 329/330 - 5/19 - 2 / 140: rias - ria
# 329/330 - 5/19 - 3 / 140: falhas - falha
# 329/330 - 5/19 - 4 / 140: campos - campo
# 329/330 - 6/19 - 1 / 22: bacia - bacia -- skip lemma
# 329/330 - 7/19 - 1 / 38: campo - campo -- skip lemma
# 329/330 - 8/19 - 1 / 187: poço exploratório - poço exploratório -- skip lemma
# 329/330 - 10/19 - 1 / 287: turret - turret -- skip lemma
# 329/330 - 10/19 - 2 / 287: risers - riser
# 329/330 - 10/19 - 3 / 287: propulsor - propulsor -- skip lemma
# 329/330 - 10/19 - 4 / 287: relé - relé -- skip lemma
# 329/330 - 10/19 - 5 / 287: trado - trado -- skip lemma
# 329/330 - 10/19 - 6 / 287: arado - arado -- skip lemma
# 329/330 - 11/19 - 1 / 387: ostra - ostra -- skip lemma
# 329/330 - 11/19 - 2 / 387: mero - mero -- skip lemma
# 329/330 - 11/19 - 3 / 387: cacao - cacao -- skip lemma
# 329/330 - 12/19 - 1 / 100: td - td -- skip lemma
# 329/330 - 12/19 - 2 / 100: cec - cec -- skip lemma
# 329/330 - 12/19 - 3 / 100: cni - cni -- skip lemma
# 329/330 - 12/19 - 4 / 100: sma - sma -- skip lemma
# 329/330 - 12/19 - 5 / 100: tp - tp -- skip lemma
# 329/330 - 12/19 - 6 / 100: semp - semp -- skip lemma
# 329/330 - 12/19 - 7 / 100: unifor - unifor -- skip lemma
# 329/330 - 14/19 - 1 / 65: espirito santo - espirito santo -- skip lemma
# 329/330 - 14/19 - 2 / 65: ico - ico -- skip lemma
# 329/330 - 14/19 - 3 / 65: campos - campo
# 329/330 - 16/19 - 1 / 284: pu - pu -- skip lemma
# 329/330 - 16/19 - 2 / 284: re - re -- skip lemma
# 329/330 - 16/19 - 3 / 284: pet - pet -- skip lemma
# 329/330 - 16/19 - 4 / 284: amina - amina -- skip lemma
# 329/330 - 16/19 - 5 / 284: co - co -- skip lemma
# 329/330 - 16/19 - 6 / 284: éster - éster -- skip lemma
# 329/330 - 16/19 - 7 / 284: poli - poli -- skip lemma
# 329/330 - 17/19 - 1 / 702: tonian - tonian -- skip lemma
# 329/330 - 17/19 - 2 / 702: toniano - toniano -- skip lemma
# 329/330 - 18/19 - 1 / 159: gas - gas -- skip lemma
# 329/330 - 18/19 - 2 / 159: gás - gás -- skip lemma
# 329/330 - 18/19 - 3 / 159: oleo - oleo -- skip lemma
# 329/330 - 18/19 - 4 / 159: óleo - óleo -- skip lemma
# 329/330 - 18/19 - 5 / 159: agua - agua -- skip lemma
# 329/330 - 18/19 - 6 / 159: petroleo - petroleo -- skip lemma
# 329/330 - 18/19 - 7 / 159: água - água -- skip lemma
# 329/330 - 18/19 - 8 / 159: petróleo - petróleo -- skip lemma
# 329/330 - 19/19 - 1 / 125: oriente médio - oriente médio -- skip lemma
# 329/330 - 19/19 - 2 / 125: catar - catar -- skip lemma
# 329/330 - 19/19 - 3 / 125: pei - pei -- skip lemma
# 329/330 - 19/19 - 4 / 125: espírito santo - espírito santo -- skip lemma
# build: 1.031221866607666330/330 - 2/19 - 1 / 926: rocha - rocha -- skip lemma
# 330/330 - 2/19 - 2 / 926: vulcanica - vulcanico
# 330/330 - 2/19 - 3 / 926: detrito - detrito -- skip lemma
# 330/330 - 2/19 - 4 / 926: pilares - pilar
# 330/330 - 2/19 - 5 / 926: areias - areia
# 330/330 - 2/19 - 6 / 926: fluidização - fluidização -- skip lemma
# 330/330 - 2/19 - 7 / 926: cré - cré -- skip lemma
# 330/330 - 2/19 - 8 / 926: maciço - maciço -- skip lemma
# 330/330 - 2/19 - 9 / 926: areia - areia -- skip lemma
# 330/330 - 2/19 - 10 / 926: falha - falha -- skip lemma
# 330/330 - 2/19 - 11 / 926: detritos - detrito
# 330/330 - 2/19 - 12 / 926: ilita - ilita -- skip lemma
# 330/330 - 2/19 - 13 / 926: atrito - atrito -- skip lemma
# 330/330 - 2/19 - 14 / 926: sal - sal -- skip lemma
# 330/330 - 2/19 - 15 / 926: raiz - raiz -- skip lemma
# 330/330 - 2/19 - 16 / 926: alita - alita -- skip lemma
# 330/330 - 2/19 - 17 / 926: argila - argila -- skip lemma
# 330/330 - 2/19 - 18 / 926: lisa - liso
# 330/330 - 2/19 - 19 / 926: escorregamento - escorregamento -- skip lemma
# 330/330 - 2/19 - 20 / 926: sima - sima -- skip lemma
# 330/330 - 3/19 - 1 / 78: metódo dos elementos finitos - metódo de o elemento finito
# 330/330 - 3/19 - 2 / 78: método - método -- skip lemma
# 330/330 - 4/19 - 1 / 41: submarino - submarino -- skip lemma
# 330/330 - 5/19 - 1 / 140: dutovia - dutovia -- skip lemma
# 330/330 - 5/19 - 2 / 140: duto - duto -- skip lemma
# 330/330 - 5/19 - 3 / 140: riacho - riacho -- skip lemma
# 330/330 - 5/19 - 4 / 140: lacustre - lacustre -- skip lemma
# 330/330 - 5/19 - 5 / 140: rias - ria
# 330/330 - 5/19 - 6 / 140: córrego - córrego -- skip lemma
# 330/330 - 5/19 - 7 / 140: falésia - falésia -- skip lemma
# 330/330 - 7/19 - 1 / 38: campo - campo -- skip lemma
# 330/330 - 9/19 - 1 / 886: colúvio - colúvio -- skip lemma
# 330/330 - 9/19 - 2 / 886: costas - costa
# 330/330 - 9/19 - 3 / 886: embasamento - embasamento -- skip lemma
# 330/330 - 10/19 - 1 / 287: relé - relé -- skip lemma
# 330/330 - 10/19 - 2 / 287: equipamento - equipamento -- skip lemma
# 330/330 - 10/19 - 3 / 287: trado - trado -- skip lemma
# 330/330 - 10/19 - 4 / 287: pert - pert -- skip lemma
# 330/330 - 10/19 - 5 / 287: arado - arado -- skip lemma
# 330/330 - 11/19 - 1 / 387: ostra - ostra -- skip lemma
# 330/330 - 11/19 - 2 / 387: irai - irai -- skip lemma
# 330/330 - 11/19 - 3 / 387: serra - serra -- skip lemma
# 330/330 - 11/19 - 4 / 387: mero - mero -- skip lemma
# 330/330 - 11/19 - 5 / 387: cacao - cacao -- skip lemma
# 330/330 - 12/19 - 1 / 100: cni - cni -- skip lemma
# 330/330 - 12/19 - 2 / 100: argil - argil -- skip lemma
# 330/330 - 12/19 - 3 / 100: sma - sma -- skip lemma
# 330/330 - 12/19 - 4 / 100: pf - pf -- skip lemma
# 330/330 - 12/19 - 5 / 100: semp - semp -- skip lemma
# 330/330 - 13/19 - 1 / 45: biocombustíveis - biocombustível
# 330/330 - 14/19 - 1 / 65: alagoas - alagoa
# 330/330 - 14/19 - 2 / 65: sao paulo - sair paulo
# 330/330 - 14/19 - 3 / 65: espirito santo - espirito santo -- skip lemma
# 330/330 - 14/19 - 4 / 65: sergipe - sergipe -- skip lemma
# 330/330 - 14/19 - 5 / 65: ico - ico -- skip lemma
# 330/330 - 14/19 - 6 / 65: parana - parana -- skip lemma
# 330/330 - 14/19 - 7 / 65: santos - santos -- skip lemma
# 330/330 - 16/19 - 1 / 284: cod - cod -- skip lemma
# 330/330 - 16/19 - 2 / 284: pu - pu -- skip lemma
# 330/330 - 16/19 - 3 / 284: soluto - soluto -- skip lemma
# 330/330 - 16/19 - 4 / 284: re - re -- skip lemma
# 330/330 - 16/19 - 5 / 284: pet - pet -- skip lemma
# 330/330 - 16/19 - 6 / 284: cot - cot -- skip lemma
# 330/330 - 16/19 - 7 / 284: co - co -- skip lemma
# 330/330 - 16/19 - 8 / 284: poli - poli -- skip lemma
# 330/330 - 18/19 - 1 / 159: gas - gas -- skip lemma
# 330/330 - 18/19 - 2 / 159: gás - gás -- skip lemma
# 330/330 - 18/19 - 3 / 159: oleo - oleo -- skip lemma
# 330/330 - 18/19 - 4 / 159: óleo - óleo -- skip lemma
# 330/330 - 18/19 - 5 / 159: agua - agua -- skip lemma
# 330/330 - 18/19 - 6 / 159: petroleo - petroleo -- skip lemma
# 330/330 - 18/19 - 7 / 159: água - água -- skip lemma
# 330/330 - 18/19 - 8 / 159: água líquida - água líquido
# 330/330 - 18/19 - 9 / 159: petróleo - petróleo -- skip lemma
# 330/330 - 19/19 - 1 / 125: argentina - argentino
# 330/330 - 19/19 - 2 / 125: catar - catar -- skip lemma
# 330/330 - 19/19 - 3 / 125: santos - santos -- skip lemma
# 330/330 - 19/19 - 4 / 125: chile - chile -- skip lemma
# 330/330 - 19/19 - 5 / 125: região sul - região sul -- skip lemma
# 330/330 - 19/19 - 6 / 125: eua - eua -- skip lemma
# 330/330 - 19/19 - 7 / 125: pei - pei -- skip lemma
# 330/330 - 19/19 - 8 / 125: cuba - cuba -- skip lemma
# 330/330 - 19/19 - 9 / 125: espírito santo - espírito santo -- skip lemma
# 330/330 - 19/19 - 10 / 125: paquistão - paquistão -- skip lemma
# build: 0.7328040599822998

# %%
# Stats
all_tags = []
[all_tags.extend(files[x]['tags_frequency']) for x in files]
all_tags = set(all_tags)

stats = "File;%NE;NE;TTR;SENT;TOKENS"
for file in sorted(files, reverse=True, key=lambda x: sum([files[x]['tags_frequency'].count(y) for y in set(files[x]['tags_frequency'])]) / files[x]['tokens']):
    stats += "\n{};{};{};{};{};{}".format(
        file, 
        sum([files[file]['tags_frequency'].count(y) for y in set(files[file]['tags_frequency'])]) / files[file]['tokens'],
        sum([files[file]['tags_frequency'].count(y) for y in set(files[file]['tags_frequency'])]),
        len(files[file]['types']) / files[file]['tokens'],
        files[file]['sentences'],
        files[file]['tokens']
        )
with open("files_stats.csv", "w") as f:
    f.write(stats)
print(stats + "\n")

stats = "Tag;NE;FILES"
for tag in sorted(all_tags, reverse=True, key=lambda x: sum([files[y]['tags_frequency'].count(x) for y in files])):
    stats += "\n{};{};{}".format(
        tag,
        sum([files[y]['tags_frequency'].count(tag) for y in files]),
        len(list(filter(lambda x: tag in files[x]['tags_frequency'], files)))
    )
with open("tags_stats.csv", "w") as f:
    f.write(stats)
print(stats + "\n")
# Out:
# ;203;0.26073446327683614;257;7080
# 180-20140922-MONOGRAFIA_0_entity.conllu;0.028633923245177967;144;0.25412606880095445;181;5029
# 309-20150408-MONOGRAFIA_0_entity.conllu;0.02859662810814478;843;0.13959089521354184;1169;29479
# 234-20150409-TESEMSC_0_entity.conllu;0.028497576736672053;441;0.13621970920840065;588;15475
# 97-20140928-MONOGRAFIA_0_entity.conllu;0.028290485607558778;515;0.17710393320149417;783;18204
# 344-20150401-TESEMSC_0_entity.conllu;0.009517386091127098;127;0.22886690647482014;577;13344
# 410-20150630-MONOGRAFIA_0_entity.conllu;0.009386192416944548;76;0.23650734840064222;287;8097
# 132-20140916-TESEMSC_0_entity.conllu;0.00930040301746409;180;0.14400124005373566;676;19354
# 332-20140804-MONOGRAFIA_0_entity.conllu;0.009294465568229826;110;0.181326573722011;338;11835
# 342-20150331-TESEMSC_0_entity.conllu;0.009270922557565375;184;0.14919131354864715;946;19847
# 4-20140915-TESEDSC_0_entity.conllu;0.009142242538316752;170;0.13578919064264589;877;18595
# 317-20150703-TESEMSC_0_entity.conllu;0.00888642043876701;128;0.20119411274645932;473;14404
# 347-20160623-TESEDSC_0_entity.conllu;0.00875510038641338;324;0.13502850812008538;1133;37007
# 209-20150513-MONOGRAFIA_0_entity.conllu;0.008214302012503992;180;0.1455300506548624;806;21913
# 74-20140924-TESEMSC_0_entity.conllu;0.008044243338360985;160;0.14841628959276018;776;19890
# 111-20140908-TESEMSC_0_entity.conllu;0.0076780185758513935;62;0.22934984520123838;267;8075
# 93-20140923-TESEDSC_0_entity.conllu;0.007075471698113208;195;0.10243105950653121;1082;27560
# 308-20150413-MONOGRAFIA_0_entity.conllu;0.006906720471829893;89;0.17080552537637747;479;12886
# 232-20150409-MONOGRAFIA_0_entity.conllu;0.006401862359959261;88;0.16091954022988506;541;13746
# 407-20160614-MONOGRAFIA_0_entity.conllu;0.006255346449957229;117;0.16151625320786997;675;18704
# 44-20150519-MONOGRAFIA_0_entity.conllu;0.005569715850089682;59;0.19182478995563107;489;10593
# 302-20150811-TESEMSC_0_entity.conllu;0.004959046080124812;178;0.12280604000668635;1222;35894
# 124-20121105-MONOGRAFIA_0_entity.conllu;0.004430124848973017;55;0.1688280306081353;471;12415
# 383-20160614-TESEDSC_0_entity.conllu;0.003991374959856861;87;0.1681882827912098;676;21797
# 112-20141112-TESEMSC_0_entity.conllu;0.002320185614849188;47;0.1505158710569186;685;20257
# 203-20140929-MONOGRAFIA_0_entity.conllu;0.0014230271668822768;11;0.2108667529107374;264;7730
#
# Tag;NE;FILES
# FLUIDO;34565;325
# QUÍMICA;25610;296
# LITOLOGIA;15396;322
# MÉTODO;9588;319
# INSTRUMENTO;8726;315
# PRODUTO;8273;193
# LOCAL:GEO;6431;303
# BACIA;4214;261
# LOCAL:POL;2895;228
# CAMPO:TIPO;2383;242
# BACIA:TIPO;1826;110
# UNIDADE_LITOESTRATIGRÁFICA;1666;98
# CAMPO;1224;185
# ORGANIZAÇÃO;1219;135
# TRANSPORTE;829;119
# POÇO:TIPO;695;66
# GEOCRONOLOGIA;666;54
# LOCAL:ORG;420;94
# POÇO;12;7

# %%
# Save tagged files
if os.path.isdir("tagged"):
    shutil.rmtree("tagged")
os.mkdir("tagged")
for file in files:
    with open("tagged/{}".format(file), "w") as f:
        f.write(files[file]['output'])
    #os.system("meld --diff {}/{} tagged/{}".format(conllu_folder, file, file))

# %%
# Find from which word a lemma came
def GetKey(dictA, val):
    for key, value in dictA.items():
        if val == value:
            return key
    return "key doesn't exist"

GetKey(lemmas, "presença")
